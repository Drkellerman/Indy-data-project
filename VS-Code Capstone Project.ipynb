# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
Indy_EconData= pd.read_csv("Indy_EconData.csv")

# %%
Indy_EconData= Indy_EconData.iloc[300:372,:]

# %%
Indy_EconData= Indy_EconData.rename(columns= {'INDI918UR': 'Unemployment Rate'})
Indy_EconData= Indy_EconData.rename(columns= {'observation_date': 'Monthly_Data'})

Indy_EconData
# Out:
#     Monthly_Data  Unemployment Rate
# 300     1/1/2015                5.2
# 301     2/1/2015                5.0
# 302     3/1/2015                4.8
# 303     4/1/2015                4.7
# 304     5/1/2015                4.5
# 305     6/1/2015                4.4
# 306     7/1/2015                4.3
# 307     8/1/2015                4.3
# 308     9/1/2015                4.2
# 309    10/1/2015                4.2
# 310    11/1/2015                4.2
# 311    12/1/2015                4.3
# 312     1/1/2016                4.3
# 313     2/1/2016                4.3
# 314     3/1/2016                4.3
# 315     4/1/2016                4.2
# 316     5/1/2016                4.1
# 317     6/1/2016                4.0
# 318     7/1/2016                4.0
# 319     8/1/2016                3.9
# 320     9/1/2016                3.9
# 321    10/1/2016                3.8
# 322    11/1/2016                3.8
# 323    12/1/2016                3.7
# 324     1/1/2017                3.6
# ...

# %%
Indy_PopData2020 =pd.read_csv("Indy_PopData2020.csv")

# %%
pd.set_option('display.max_rows', None)
Indy_PopData2020
pd.read_csv ("Indy_PopData2020.csv")
# Out:
#                                      Label (Grouping)  \
# 0                          Population Age 16 and Over
# 1                                   EMPLOYMENT STATUS
# 2                                            Employed
# 3                                  Not in Labor Force
# 4                 Employed Population Age 16 and Over
# 5                                     CLASS OF WORKER
# 6           Private for-profit wage and salary wor...
# 7                 Employee of private company workers
# 8           Self-employed in own incorporated busi...
# 9           Private not-for-profit wage and salary...
# 10                           Local government workers
# 11                           State government workers
# 12                         Federal government workers
# 13          Self-employed in own not incorporated ...
# 14                              Unpaid family workers
# 15                                         OCCUPATION
# ...

# %%
Indy_PopData2020.drop(['Indianapolis city (balance), Indiana!!With a Disability!!Estimate',
                      'Indianapolis city (balance), Indiana!!No Disability!!Estimate',
                      'Indianapolis city (balance), Indiana!!Total Civilian Noninstitutionalized Population!!Margin of Error',
                      'Indianapolis city (balance), Indiana!!No Disability!!Margin of Error',
                      'Indianapolis city (balance), Indiana!!With a Disability!!Margin of Error'],axis=1, inplace=True)

#Indianapolis city (balance), Indiana!!With a Disability!!Estimate,
#Estimate, Indianapolis city (balance)
#Indiana!!With a Disability!!Margin of Error,
#Indianapolis city (balance), Indiana!!No Disability!!Estimate,
#Indianapolis city (balance), Indiana!!No Disability!!Margin of Error

# %%
Indy_PopData2020=Indy_PopData2020.rename(columns= {'Indianapolis city (balance), Indiana!!Total Civilian Noninstitutionalized Population!!Estimate': 'Indianapolis City Population'})

# %%
Indy_PopData2020
# Out:
#                                      Label (Grouping)  \
# 0                          Population Age 16 and Over
# 1                                   EMPLOYMENT STATUS
# 2                                            Employed
# 3                                  Not in Labor Force
# 4                 Employed Population Age 16 and Over
# 5                                     CLASS OF WORKER
# 6           Private for-profit wage and salary wor...
# 7                 Employee of private company workers
# 8           Self-employed in own incorporated busi...
# 9           Private not-for-profit wage and salary...
# 10                           Local government workers
# 11                           State government workers
# 12                         Federal government workers
# 13          Self-employed in own not incorporated ...
# 14                              Unpaid family workers
# 15                                         OCCUPATION
# ...

# %%
Indy_PopData2019 =pd.read_csv("Indy_PopData2019.csv")

# %%
pd.set_option('display.max_rows', None)
Indy_PopData2019
pd.read_csv ("Indy_PopData2019.csv")
# Out:
#                                      Label (Grouping)  \
# 0                          Population Age 16 and Over
# 1                                   EMPLOYMENT STATUS
# 2                                            Employed
# 3                                  Not in Labor Force
# 4                 Employed Population Age 16 and Over
# 5                                     CLASS OF WORKER
# 6           Private for-profit wage and salary wor...
# 7                 Employee of private company workers
# 8           Self-employed in own incorporated busi...
# 9           Private not-for-profit wage and salary...
# 10                           Local government workers
# 11                           State government workers
# 12                         Federal government workers
# 13          Self-employed in own not incorporated ...
# 14                              Unpaid family workers
# 15                                         OCCUPATION
# ...

# %%
Indy_PopData2019.drop(['Indianapolis city (balance), Indiana!!With a Disability!!Estimate',
                      'Indianapolis city (balance), Indiana!!No Disability!!Estimate',
                      'Indianapolis city (balance), Indiana!!Total Civilian Noninstitutionalized Population!!Margin of Error',
                      'Indianapolis city (balance), Indiana!!No Disability!!Margin of Error',
                      'Indianapolis city (balance), Indiana!!With a Disability!!Margin of Error'],axis=1, inplace=True)

# %%
Indy_PopData2019=Indy_PopData2019.rename(columns= {'Indianapolis city (balance), Indiana!!Total Civilian Noninstitutionalized Population!!Estimate': 'Indianapolis City Population'})

# %%
Indy_PopData2019
# Out:
#                                      Label (Grouping)  \
# 0                          Population Age 16 and Over
# 1                                   EMPLOYMENT STATUS
# 2                                            Employed
# 3                                  Not in Labor Force
# 4                 Employed Population Age 16 and Over
# 5                                     CLASS OF WORKER
# 6           Private for-profit wage and salary wor...
# 7                 Employee of private company workers
# 8           Self-employed in own incorporated busi...
# 9           Private not-for-profit wage and salary...
# 10                           Local government workers
# 11                           State government workers
# 12                         Federal government workers
# 13          Self-employed in own not incorporated ...
# 14                              Unpaid family workers
# 15                                         OCCUPATION
# ...

# %%
Indy_PopData2018 =pd.read_csv("Indy_PopData2018.csv")

# %%
pd.set_option('display.max_rows', None)
Indy_PopData2018
pd.read_csv ("Indy_PopData2018.csv")
# Out:
#                                      Label (Grouping)  \
# 0                          Population Age 16 and Over
# 1                                   EMPLOYMENT STATUS
# 2                                            Employed
# 3                                  Not in Labor Force
# 4                 Employed Population Age 16 and Over
# 5                                     CLASS OF WORKER
# 6           Private for-profit wage and salary wor...
# 7                 Employee of private company workers
# 8           Self-employed in own incorporated busi...
# 9           Private not-for-profit wage and salary...
# 10                           Local government workers
# 11                           State government workers
# 12                         Federal government workers
# 13          Self-employed in own not incorporated ...
# 14                              Unpaid family workers
# 15                                         OCCUPATION
# ...

# %%
Indy_PopData2018.drop(['Indianapolis city (balance), Indiana!!With a Disability!!Estimate',
                      'Indianapolis city (balance), Indiana!!No Disability!!Estimate',
                      'Indianapolis city (balance), Indiana!!Total Civilian Noninstitutionalized Population!!Margin of Error',
                      'Indianapolis city (balance), Indiana!!No Disability!!Margin of Error',
                      'Indianapolis city (balance), Indiana!!With a Disability!!Margin of Error'],axis=1, inplace=True)

# %%
Indy_PopData2018=Indy_PopData2018.rename(columns= {'Indianapolis city (balance), Indiana!!Total Civilian Noninstitutionalized Population!!Estimate': 'Indianapolis City Population'})

# %%
Indy_PopData2018
# Out:
#                                      Label (Grouping)  \
# 0                          Population Age 16 and Over
# 1                                   EMPLOYMENT STATUS
# 2                                            Employed
# 3                                  Not in Labor Force
# 4                 Employed Population Age 16 and Over
# 5                                     CLASS OF WORKER
# 6           Private for-profit wage and salary wor...
# 7                 Employee of private company workers
# 8           Self-employed in own incorporated busi...
# 9           Private not-for-profit wage and salary...
# 10                           Local government workers
# 11                           State government workers
# 12                         Federal government workers
# 13          Self-employed in own not incorporated ...
# 14                              Unpaid family workers
# 15                                         OCCUPATION
# ...

# %%
Indy_PopData2017 =pd.read_csv("Indy_PopData2017.csv")

# %%
pd.set_option('display.max_rows', None)
Indy_PopData2017
pd.read_csv ("Indy_PopData2017.csv")
# Out:
#                                      Label (Grouping)  \
# 0                          Population Age 16 and Over
# 1                                   EMPLOYMENT STATUS
# 2                                            Employed
# 3                                  Not in Labor Force
# 4                 Employed Population Age 16 and Over
# 5                                     CLASS OF WORKER
# 6          Private for-profit wage and salary workers
# 7                 Employee of private company workers
# 8       Self-employed in own incorporated business...
# 9       Private not-for-profit wage and salary wor...
# 10                           Local government workers
# 11                           State government workers
# 12                         Federal government workers
# 13      Self-employed in own not incorporated busi...
# 14                              Unpaid family workers
# 15                                         OCCUPATION
# ...

# %%
Indy_PopData2017.drop(['Indianapolis city (balance), Indiana!!With a Disability!!Estimate',
                      'Indianapolis city (balance), Indiana!!No Disability!!Estimate',
                      'Indianapolis city (balance), Indiana!!Total Civilian Noninstitutionalized Population!!Margin of Error',
                      'Indianapolis city (balance), Indiana!!No Disability!!Margin of Error',
                      'Indianapolis city (balance), Indiana!!With a Disability!!Margin of Error'],axis=1, inplace=True)

# %%
Indy_PopData2017=Indy_PopData2017.rename(columns= {'Indianapolis city (balance), Indiana!!Total Civilian Noninstitutionalized Population!!Estimate': 'Indianapolis City Population'})

# %%
Indy_PopData2017
# Out:
#                                      Label (Grouping)  \
# 0                          Population Age 16 and Over
# 1                                   EMPLOYMENT STATUS
# 2                                            Employed
# 3                                  Not in Labor Force
# 4                 Employed Population Age 16 and Over
# 5                                     CLASS OF WORKER
# 6          Private for-profit wage and salary workers
# 7                 Employee of private company workers
# 8       Self-employed in own incorporated business...
# 9       Private not-for-profit wage and salary wor...
# 10                           Local government workers
# 11                           State government workers
# 12                         Federal government workers
# 13      Self-employed in own not incorporated busi...
# 14                              Unpaid family workers
# 15                                         OCCUPATION
# ...

# %%
Indy_PopData2016 =pd.read_csv("Indy_PopData2016.csv")

# %%
pd.set_option('display.max_rows', None)
Indy_PopData2016
pd.read_csv ("Indy_PopData2016.csv")
# Out:
#                                      Label (Grouping)  \
# 0                          Population Age 16 and Over
# 1                                   EMPLOYMENT STATUS
# 2                                            Employed
# 3                                  Not in Labor Force
# 4                 Employed Population Age 16 and Over
# 5                                     CLASS OF WORKER
# 6          Private for-profit wage and salary workers
# 7                 Employee of private company workers
# 8       Self-employed in own incorporated business...
# 9       Private not-for-profit wage and salary wor...
# 10                           Local government workers
# 11                           State government workers
# 12                         Federal government workers
# 13      Self-employed in own not incorporated busi...
# 14                              Unpaid family workers
# 15                                         OCCUPATION
# ...

# %%
Indy_PopData2016.drop(['Indianapolis city (balance), Indiana!!With a Disability!!Estimate',
                      'Indianapolis city (balance), Indiana!!No Disability!!Estimate',
                      'Indianapolis city (balance), Indiana!!Total Civilian Noninstitutionalized Population!!Margin of Error',
                      'Indianapolis city (balance), Indiana!!No Disability!!Margin of Error',
                      'Indianapolis city (balance), Indiana!!With a Disability!!Margin of Error'],axis=1, inplace=True)

# %%
Indy_PopData2016=Indy_PopData2016.rename(columns= {'Indianapolis city (balance), Indiana!!Total Civilian Noninstitutionalized Population!!Estimate': 'Indianapolis City Population'})

# %%
Indy_PopData2016
# Out:
#                                      Label (Grouping)  \
# 0                          Population Age 16 and Over
# 1                                   EMPLOYMENT STATUS
# 2                                            Employed
# 3                                  Not in Labor Force
# 4                 Employed Population Age 16 and Over
# 5                                     CLASS OF WORKER
# 6          Private for-profit wage and salary workers
# 7                 Employee of private company workers
# 8       Self-employed in own incorporated business...
# 9       Private not-for-profit wage and salary wor...
# 10                           Local government workers
# 11                           State government workers
# 12                         Federal government workers
# 13      Self-employed in own not incorporated busi...
# 14                              Unpaid family workers
# 15                                         OCCUPATION
# ...

# %%
Indy_PopData2015 =pd.read_csv("Indy_PopData2015.csv")

# %%
pd.set_option('display.max_rows', None)
Indy_PopData2015
pd.read_csv ("Indy_PopData2015.csv")
# Out:
#                                      Label (Grouping)  \
# 0                          Population Age 16 and Over
# 1                                   EMPLOYMENT STATUS
# 2                                            Employed
# 3                                  Not in Labor Force
# 4                 Employed Population Age 16 and Over
# 5                                     CLASS OF WORKER
# 6          Private for-profit wage and salary workers
# 7                 Employee of private company workers
# 8       Self-employed in own incorporated business...
# 9       Private not-for-profit wage and salary wor...
# 10                           Local government workers
# 11                           State government workers
# 12                         Federal government workers
# 13      Self-employed in own not incorporated busi...
# 14                              Unpaid family workers
# 15                                         OCCUPATION
# ...

# %%
Indy_PopData2015.drop(['Indianapolis city (balance), Indiana!!With a Disability!!Estimate',
                      'Indianapolis city (balance), Indiana!!No Disability!!Estimate',
                      'Indianapolis city (balance), Indiana!!Total Civilian Noninstitutionalized Population!!Margin of Error',
                      'Indianapolis city (balance), Indiana!!No Disability!!Margin of Error',
                      'Indianapolis city (balance), Indiana!!With a Disability!!Margin of Error'],axis=1, inplace=True)

# %%
Indy_PopData2015=Indy_PopData2015.rename(columns= {'Indianapolis city (balance), Indiana!!Total Civilian Noninstitutionalized Population!!Estimate': 'Indianapolis City Population'})

# %%
Indy_PopData2015
# Out:
#                                      Label (Grouping)  \
# 0                          Population Age 16 and Over
# 1                                   EMPLOYMENT STATUS
# 2                                            Employed
# 3                                  Not in Labor Force
# 4                 Employed Population Age 16 and Over
# 5                                     CLASS OF WORKER
# 6          Private for-profit wage and salary workers
# 7                 Employee of private company workers
# 8       Self-employed in own incorporated business...
# 9       Private not-for-profit wage and salary wor...
# 10                           Local government workers
# 11                           State government workers
# 12                         Federal government workers
# 13      Self-employed in own not incorporated busi...
# 14                              Unpaid family workers
# 15                                         OCCUPATION
# ...

# %%
Indy_PopMigration2 =pd.read_csv("Indy_PopMigration2.csv")

# %%
Indy_PopMigration2=Indy_PopMigration2.rename(columns= {'NETMIGNACS018097': 'Indianapolis City Population Out-Migration'})
Indy_PopMigration2=Indy_PopMigration2.rename(columns= {'observation_date': 'Monthly_Data'})

Indy_PopMigration2
# Out:
#   Monthly_Data  Indianapolis City Population Out-Migration
# 0     1/1/2015                                      -11468
# 1     1/1/2016                                      -12971
# 2     1/1/2017                                      -11733
# 3     1/1/2018                                      -14289
# 4     1/1/2019                                      -14028
# 5     1/1/2020                                      -11554
