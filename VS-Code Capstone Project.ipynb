# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
Indy_EconData= pd.read_csv("Indy_EconData.csv")

# %%
Indy_EconData= Indy_EconData.iloc[300:372,:]

# %%
Indy_EconData
# Out:
#     observation_date  INDI918UR
# 300         1/1/2015        5.2
# 301         2/1/2015        5.0
# 302         3/1/2015        4.8
# 303         4/1/2015        4.7
# 304         5/1/2015        4.5
# 305         6/1/2015        4.4
# 306         7/1/2015        4.3
# 307         8/1/2015        4.3
# 308         9/1/2015        4.2
# 309        10/1/2015        4.2
# 310        11/1/2015        4.2
# 311        12/1/2015        4.3
# 312         1/1/2016        4.3
# 313         2/1/2016        4.3
# 314         3/1/2016        4.3
# 315         4/1/2016        4.2
# 316         5/1/2016        4.1
# 317         6/1/2016        4.0
# 318         7/1/2016        4.0
# 319         8/1/2016        3.9
# 320         9/1/2016        3.9
# 321        10/1/2016        3.8
# 322        11/1/2016        3.8
# 323        12/1/2016        3.7
# 324         1/1/2017        3.6
# 325         2/1/2017        3.4
# 326         3/1/2017        3.3
# 327         4/1/2017        3.2
# ...

# %%
Indy_PopData2023 =pd.read_csv("Indy_PopData2023.csv")

# %%
pd.set_option('display.max_rows', None)
Indy_PopData2023
# Out:
#                                      Label (Grouping)  \
# 0                          Population Age 16 and Over
# 1                                   EMPLOYMENT STATUS
# 2                                            Employed
# 3                                  Not in Labor Force
# 4                 Employed Population Age 16 and Over
# 5                                     CLASS OF WORKER
# 6           Private for-profit wage and salary wor...
# 7                 Employee of private company workers
# 8           Self-employed in own incorporated busi...
# 9           Private not-for-profit wage and salary...
# 10                           Local government workers
# 11                           State government workers
# 12                         Federal government workers
# 13          Self-employed in own not incorporated ...
# 14                              Unpaid family workers
# 15                                         OCCUPATION
# ...

# %%
Indy_PopData2022 =pd.read_csv("Indy_PopData2022.csv")

# %%
Indy_PopData2022["Year"]= "2022"
Indy_PopData2023["Year"]= "2023"

# %%
Indy_Pop= pd.concat ([Indy_PopData2022, Indy_PopData2023])
Indy_Pop
# Out:
#                                      Label (Grouping)  \
# 0                          Population Age 16 and Over
# 1                                   EMPLOYMENT STATUS
# 2                                            Employed
# 3                                  Not in Labor Force
# 4                 Employed Population Age 16 and Over
# 5                                     CLASS OF WORKER
# 6           Private for-profit wage and salary wor...
# 7                 Employee of private company workers
# 8           Self-employed in own incorporated busi...
# 9           Private not-for-profit wage and salary...
# 10                           Local government workers
# 11                           State government workers
# 12                         Federal government workers
# 13          Self-employed in own not incorporated ...
# 14                              Unpaid family workers
# 15                                         OCCUPATION
# ...

# %%
pd.set_option('display.max_rows', None)
Indy_PopData2022
pd.read_csv ("Indy_PopData2022.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 pd.set_option('display.max_rows', None)
# ----> 2 Indy_PopData2022
#       3 pd.read_csv ("Indy_PopData2022.csv")
#
# NameError: name 'Indy_PopData2022' is not defined

# %%
Indy_PopData2021 =pd.read_csv("Indy_PopData2021.csv")

# %%
pd.set_option('display.max_rows', None)
Indy_PopData2021
pd.read_csv ("Indy_PopData2021.csv")
# Out:
#                                      Label (Grouping)  \
# 0                          Population Age 16 and Over
# 1                                   EMPLOYMENT STATUS
# 2                                            Employed
# 3                                  Not in Labor Force
# 4                 Employed Population Age 16 and Over
# 5                                     CLASS OF WORKER
# 6           Private for-profit wage and salary wor...
# 7                 Employee of private company workers
# 8           Self-employed in own incorporated busi...
# 9           Private not-for-profit wage and salary...
# 10                           Local government workers
# 11                           State government workers
# 12                         Federal government workers
# 13          Self-employed in own not incorporated ...
# 14                              Unpaid family workers
# 15                                         OCCUPATION
# ...

# %%
Indy_PopData2020 =pd.read_csv("Indy_PopData2020.csv")

# %%
pd.set_option('display.max_rows', None)
Indy_PopData2020
pd.read_csv ("Indy_PopData2020.csv")
# Out:
#                                      Label (Grouping)  \
# 0                          Population Age 16 and Over
# 1                                   EMPLOYMENT STATUS
# 2                                            Employed
# 3                                  Not in Labor Force
# 4                 Employed Population Age 16 and Over
# 5                                     CLASS OF WORKER
# 6           Private for-profit wage and salary wor...
# 7                 Employee of private company workers
# 8           Self-employed in own incorporated busi...
# 9           Private not-for-profit wage and salary...
# 10                           Local government workers
# 11                           State government workers
# 12                         Federal government workers
# 13          Self-employed in own not incorporated ...
# 14                              Unpaid family workers
# 15                                         OCCUPATION
# ...

# %%
Indy_PopData2019 =pd.read_csv("Indy_PopData2019.csv")

# %%
pd.set_option('display.max_rows', None)
Indy_PopData2019
pd.read_csv ("Indy_PopData2019.csv")
# Out:
#                                      Label (Grouping)  \
# 0                          Population Age 16 and Over
# 1                                   EMPLOYMENT STATUS
# 2                                            Employed
# 3                                  Not in Labor Force
# 4                 Employed Population Age 16 and Over
# 5                                     CLASS OF WORKER
# 6           Private for-profit wage and salary wor...
# 7                 Employee of private company workers
# 8           Self-employed in own incorporated busi...
# 9           Private not-for-profit wage and salary...
# 10                           Local government workers
# 11                           State government workers
# 12                         Federal government workers
# 13          Self-employed in own not incorporated ...
# 14                              Unpaid family workers
# 15                                         OCCUPATION
# ...

# %%
Indy_PopData2019 =pd.read_csv("Indy_PopData2019.csv")

# %%
pd.set_option('display.max_rows', None)
Indy_PopData2019
pd.read_csv ("Indy_PopData2019.csv")
# Out:
#                                      Label (Grouping)  \
# 0                          Population Age 16 and Over
# 1                                   EMPLOYMENT STATUS
# 2                                            Employed
# 3                                  Not in Labor Force
# 4                 Employed Population Age 16 and Over
# 5                                     CLASS OF WORKER
# 6           Private for-profit wage and salary wor...
# 7                 Employee of private company workers
# 8           Self-employed in own incorporated busi...
# 9           Private not-for-profit wage and salary...
# 10                           Local government workers
# 11                           State government workers
# 12                         Federal government workers
# 13          Self-employed in own not incorporated ...
# 14                              Unpaid family workers
# 15                                         OCCUPATION
# ...

# %%
Indy_PopData2018 =pd.read_csv("Indy_PopData2018.csv")

# %%
pd.set_option('display.max_rows', None)
Indy_PopData2018
pd.read_csv ("Indy_PopData2018.csv")
# Out:
#                                      Label (Grouping)  \
# 0                          Population Age 16 and Over
# 1                                   EMPLOYMENT STATUS
# 2                                            Employed
# 3                                  Not in Labor Force
# 4                 Employed Population Age 16 and Over
# 5                                     CLASS OF WORKER
# 6           Private for-profit wage and salary wor...
# 7                 Employee of private company workers
# 8           Self-employed in own incorporated busi...
# 9           Private not-for-profit wage and salary...
# 10                           Local government workers
# 11                           State government workers
# 12                         Federal government workers
# 13          Self-employed in own not incorporated ...
# 14                              Unpaid family workers
# 15                                         OCCUPATION
# ...

# %%
Indy_PopData2017 =pd.read_csv("Indy_PopData2017.csv")

# %%
pd.set_option('display.max_rows', None)
Indy_PopData2017
pd.read_csv ("Indy_PopData2017.csv")
# Out:
#                                      Label (Grouping)  \
# 0                          Population Age 16 and Over
# 1                                   EMPLOYMENT STATUS
# 2                                            Employed
# 3                                  Not in Labor Force
# 4                 Employed Population Age 16 and Over
# 5                                     CLASS OF WORKER
# 6          Private for-profit wage and salary workers
# 7                 Employee of private company workers
# 8       Self-employed in own incorporated business...
# 9       Private not-for-profit wage and salary wor...
# 10                           Local government workers
# 11                           State government workers
# 12                         Federal government workers
# 13      Self-employed in own not incorporated busi...
# 14                              Unpaid family workers
# 15                                         OCCUPATION
# ...

# %%
Indy_PopData2016 =pd.read_csv("Indy_PopData2016.csv")

# %%
pd.set_option('display.max_rows', None)
Indy_PopData2016
pd.read_csv ("Indy_PopData2016.csv")
# Out:
#                                      Label (Grouping)  \
# 0                          Population Age 16 and Over
# 1                                   EMPLOYMENT STATUS
# 2                                            Employed
# 3                                  Not in Labor Force
# 4                 Employed Population Age 16 and Over
# 5                                     CLASS OF WORKER
# 6          Private for-profit wage and salary workers
# 7                 Employee of private company workers
# 8       Self-employed in own incorporated business...
# 9       Private not-for-profit wage and salary wor...
# 10                           Local government workers
# 11                           State government workers
# 12                         Federal government workers
# 13      Self-employed in own not incorporated busi...
# 14                              Unpaid family workers
# 15                                         OCCUPATION
# ...

# %%
Indy_PopData2015 =pd.read_csv("Indy_PopData2015.csv")

# %%
pd.set_option('display.max_rows', None)
Indy_PopData2015
pd.read_csv ("Indy_PopData2015.csv")
# Out:
#                                      Label (Grouping)  \
# 0                          Population Age 16 and Over
# 1                                   EMPLOYMENT STATUS
# 2                                            Employed
# 3                                  Not in Labor Force
# 4                 Employed Population Age 16 and Over
# 5                                     CLASS OF WORKER
# 6          Private for-profit wage and salary workers
# 7                 Employee of private company workers
# 8       Self-employed in own incorporated business...
# 9       Private not-for-profit wage and salary wor...
# 10                           Local government workers
# 11                           State government workers
# 12                         Federal government workers
# 13      Self-employed in own not incorporated busi...
# 14                              Unpaid family workers
# 15                                         OCCUPATION
# ...

# %%
Indy_PopMigration2 =pd.read_csv("Indy_PopMigration2.csv")

# %%
pd.set_option('display.max_rows', None)
Indy_PopMigration2
pd.read_csv ("Indy_PopMigration2.csv")
# Out:
#   observation_date  NETMIGNACS018097
# 0         1/1/2015            -11468
# 1         1/1/2016            -12971
# 2         1/1/2017            -11733
# 3         1/1/2018            -14289
# 4         1/1/2019            -14028
# 5         1/1/2020            -11554
